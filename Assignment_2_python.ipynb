# %% [markdown]
# <a href="https://colab.research.google.com/github/batoolyasir853-coder/Python_assignment1/blob/main/Assignment_2_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Python Assignment** **2**
#
#
# ---
# ### **Topic:** Operators
# ### **Name:** Batool Yasir
# ---
#   ### **Arithmetic Operators**
# **Q1:** **Write a Python program to add two numbers and print the result.**
# **Answer:**

# %%
a=2
b=6
print(a+b)
# Out:
# 8

# %% [markdown]
# **Q2:** **Write the program to find the remainder when one number is divided by another.**
# **Answer:**

# %%
a=9
b=4
print("Remainder=",a%b)
# Out:
# Remainder= 1

# %% [markdown]
# **Q3:Write a program to calculate the square of a number using the power operator.**
# **Answer:**

# %%
num=5
print("square=",num**2)
# Out:
# square= 25

# %% [markdown]
# ---
# ### **Assignment operators**
# **Q4:Write a program that assigns a value to a variable and then increase it by 5 using an assignment operator.**
# **Answer:**

# %%
a=4
a+=5
print("a=",a)
# Out:
# a= 9

# %% [markdown]
# **Q5:Write a program that multiplies a variable by 2 using an assignment operator.**
# **Answer:**

# %%
a=9
a*=2
print("a=",a)
# Out:
# a= 18

# %% [markdown]
# **Q6:Write a program that substracts 10 from a variable using an assignment operator.**
# **Answer:**

# %%
a=26
a-=10
print("a=",a)
# Out:
# a= 16

# %% [markdown]
# ---
# ### **Comparasion operators**
# **Q7:Write a program to check whether two numbers are equal or not.**
# **Answer:**

# %%
a=9
b=8
print(a==b)
# we also used if else
# Out:
# False

# %% [markdown]
# **Q8:Write a program to check if one number is greater than another.**
# **Answer:**

# %%
a=10
b=3
print(a>b)
# Out:
# True

# %% [markdown]
# **Q9:Write a program to compare two numbers and print whether the first number is less then or equal to the second number.**
# **Answer:**

# %%
a=4
b=7
print(a<=b)
# Out:
# True

# %% [markdown]
# ---
# ### **Logical operators**
# **Q10:Write a program that checks if a number is greater than 5 and less than 20.**
# **Answer:**

# %%
num=16
print(num>5 and num<20)
# Out:
# True

# %% [markdown]
# **Q11:Write a program that checks if a number is less than 10 or greater than 20.**
# **Answer:**

# %%
num=60
print(num<10 or num>20)
# Out:
# True

# %% [markdown]
# **Q12:Write a program that uses the not operator to reverse a condition.**
# **Answer:**

# %%
num=88
print(not(num>10))
# Out:
# False

# %% [markdown]
# ---
# ### **Membership operators**
# **Q13:Write a program to check if a number exists in a given list.**
# **Answer:**

# %%
numbers=[1,2,3,5,6]
print(3 in numbers)
# Out:
# True

# %% [markdown]
# **Q14:Write a program to check if a word exists in a given string.**
# **Answer:**

# %%
text="this is my second assignment of python"
print("python" in text)
# Out:
# True

# %% [markdown]
# **Q15:Write a program to check whether a value is not present in a tuple.**
# **Answer:**

# %%
tuple=(10,20,30,40,50)
print(40 not in tuple)
# Out:
# False

# %% [markdown]
#             ***********************
#              Assignment Completed
#             ***********************
